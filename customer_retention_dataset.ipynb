# %%
#import the requred library

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
#upload the dataset or file
df=pd.read_excel('customer_retention_dataset11.xlsx')

# %%
df
# Out:
#      1Gender of respondent  2 How old are you?   \
# 0                        0                    3
# 1                        1                    2
# 2                        1                    2
# 3                        0                    2
# 4                        1                    2
# ..                     ...                  ...
# 264                      1                    2
# 265                      1                    3
# 266                      1                    4
# 267                      1                    1
# 268                      1                    4
#
#     3 Which city do you shop online from?  \
# 0                                   Delhi
# 1                                   Delhi
# 2                           Greater Noida
# 3                                 Karnal
# 4                              Bangalore
# ..                                    ...
# 264                                 Solan
# ...

# %%
data=pd.DataFrame(df)

# %%
data.head(3)
# Out:
#    1Gender of respondent  2 How old are you?   \
# 0                      0                    3
# 1                      1                    2
# 2                      1                    2
#
#   3 Which city do you shop online from?  \
# 0                                 Delhi
# 1                                 Delhi
# 2                         Greater Noida
#
#    4 What is the Pin Code of where you shop online from?  \
# 0                                             110009
# 1                                             110030
# 2                                             201308
#
#    5 Since How Long You are Shopping Online ?  \
# 0                                           5
# 1                                           5
# 2                                           4
#
#    6 How many times you have made an online purchase in the past 1 year?  \
# 0                                                  4
# 1                                                  5
# ...

# %%
data.isnull().sum()
# Out:
# 1Gender of respondent                                                   0
# 2 How old are you?                                                      0
# 3 Which city do you shop online from?                                   0
# 4 What is the Pin Code of where you shop online from?                   0
# 5 Since How Long You are Shopping Online ?                              0
#                                                                        ..
# Longer delivery period                                                  0
# Change in website/Application design                                    0
# Frequent disruption when moving from one page to another                0
# Website is as efficient as before                                       0
# Which of the Indian online retailer would you recommend to a friend?    0
# Length: 71, dtype: int64

# %% [markdown]
# BY THE "ISNULL" FUCTION WE CAN CHECK THE NULL VALUES THAT ANY NULL VALUE PRESENT IN OUR DATA SET OR NOT

# %%
sns.heatmap(data.corr().isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# we can esaly understand the naull values by heatmap in our data no null values.

# %%
data.keys()
# Out:
# Index(['1Gender of respondent', '2 How old are you? ',
#        '3 Which city do you shop online from?',
#        '4 What is the Pin Code of where you shop online from?',
#        '5 Since How Long You are Shopping Online ?',
#        '6 How many times you have made an online purchase in the past 1 year?',
#        '7 How do you access the internet while shopping on-line?',
#        '8 Which device do you use to access the online shopping?',
#        '9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ',
#        '10 What is the operating system (OS) of your device?\t\t\t\t                                          ',
#        '11 What browser do you run on your device to access the website?                                                   ',
#        'Which channel did you follow to arrive at your favorite online store for the first time?                                                              ',
# ...

# %%
data.describe()
# Out:
#        1Gender of respondent  2 How old are you?   \
# count             269.000000           269.000000
# mean                0.669145             2.959108
# std                 0.471398             1.066012
# min                 0.000000             1.000000
# 25%                 0.000000             2.000000
# 50%                 1.000000             3.000000
# 75%                 1.000000             4.000000
# max                 1.000000             5.000000
#
#        4 What is the Pin Code of where you shop online from?  \
# count                                         269.000000
# mean                                       220465.747212
# std                                        140524.341051
# min                                        110008.000000
# 25%                                        122018.000000
# 50%                                        201303.000000
# 75%                                        201310.000000
# ...

# %% [markdown]
# # statistical summary og dataset we can check by describe function

# %% [markdown]
# the describe function describe --->MINIMUM,MAXIMUM,MEAN,STANDER DAVIATION, 25,50,75 PECENTILE

# %% [markdown]
# # NO CHECK THE CORRELATION IN DATASET

# %%
plt.figure(figsize=(15,7))
sns.heatmap(data.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(15,7))
sns.barplot(x='3 Which city do you shop online from?',y='1Gender of respondent',data=data)
# Out:
# <AxesSubplot:xlabel='3 Which city do you shop online from?', ylabel='1Gender of respondent'>

# %% [markdown]
# # we can clearly understand the in wich city people do online shop in "moradabad","bulandshahr",people not use online shope also
# "delhi" and "noida" have less user as compair othe city

# %%
sns.countplot(df['1Gender of respondent'])
data["1Gender of respondent"].value_counts()
# Out:
# 1    180
# 0     89
# Name: 1Gender of respondent, dtype: int64

# %% [markdown]
# #females are more preford online shoping as compait to males

# %%
data.plot(kind='box',subplots=True,layout=(30,3),figsize=(35,25))
# Out:
# 1Gender of respondent                                                                                                                                                                                                     AxesSubplot(0.125,0.858911;0.227941x0.0210894)
# 2 How old are you?                                                                                                                                                                                                     AxesSubplot(0.398529,0.858911;0.227941x0.0210894)
# 4 What is the Pin Code of where you shop online from?                                                                                                                                                                  AxesSubplot(0.672059,0.858911;0.227941x0.0210894)
# ...

# %%
sns.countplot(df['5 Since How Long You are Shopping Online ?'])
data["5 Since How Long You are Shopping Online ?"].value_counts()
# Out:
# 5    98
# 3    65
# 4    47
# 1    43
# 2    16
# Name: 5 Since How Long You are Shopping Online ?, dtype: int64

# %%
sns.countplot(x ='5 Since How Long You are Shopping Online ?' ,data = data,color="salmon")
# Out:
# <AxesSubplot:xlabel='5 Since How Long You are Shopping Online ?', ylabel='count'>

# %%
#in the above plot we can esaly understand hove many long time use the online shoping

# %%
sns.catplot(x='5 Since How Long You are Shopping Online ?',col='1Gender of respondent',kind="count",data=data)

# %% [markdown]
# # as to male, female shoping by longer time

# %%
sns.catplot(x='6 How many times you have made an online purchase in the past 1 year?',col='1Gender of respondent',kind="count",aspect=.7,data=data)

# %% [markdown]
# #maximum 40-41  time  purchase by male in a year,female maximum perchase in a year aprox 70 time

# %%
plt.figure(figsize=(15,7))
sns.countplot(x='13 After first visit, how do you reach the online retail store?\t\t\t\t                                                   '  , data=data)
data['13 After first visit, how do you reach the online retail store?\t\t\t\t                                                   '].value_counts()
# Out:
# 1    95
# 4    86
# 3    70
# 2    18
# Name: 13 After first visit, how do you reach the online retail store?\t\t\t\t                                                   , dtype: int64

# %%
plt.figure(figsize=(10,7))
sns.countplot(x='15 What is your preferred payment Option?\t\t\t\t\t                                                                                                                               ',data=data)
data['15 What is your preferred payment Option?\t\t\t\t\t                                                                                                                               '].value_counts()
# Out:
# 1    148
# 2     76
# 4     45
# Name: 15 What is your preferred payment Option?\t\t\t\t\t                                                                                                                               , dtype: int64

# %% [markdown]
# #1 for credit card debit card, 2 for cash on delevary, 3 for wallet people like the cedit and debit card most,

# %%
data['19 Information on similar product to the one highlighted  is important for product comparison'].value_counts().head(47).plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
sns.countplot(
    data=data,
    x='19 Information on similar product to the one highlighted  is important for product comparison',
    
    color='red')
data['19 Information on similar product to the one highlighted  is important for product comparison'].value_counts()
# Out:
# 5    116
# 4     92
# 3     43
# 2     18
# Name: 19 Information on similar product to the one highlighted  is important for product comparison, dtype: int64

# %%
#25 Convenient Payment methods
sns.countplot(
    data=data,
    x='25 Convenient Payment methods',
    
    color='pink')
data['25 Convenient Payment methods'].value_counts()
# Out:
# 5    159
# 4     80
# 2     30
# Name: 25 Convenient Payment methods, dtype: int64

# %%
#2 for des-agree
#4 foe agree
#5 for strongly agree

# %%
#21 All relevant information on listed products must be stated clearly'
sns.countplot(
    data=data,
    x='21 All relevant information on listed products must be stated clearly')
data['21 All relevant information on listed products must be stated clearly'].value_counts()
# Out:
# 4    132
# 5    107
# 1     18
# 2     12
# Name: 21 All relevant information on listed products must be stated clearly, dtype: int64

# %% [markdown]
# most of people agree to  All relevant information on listed products must be stated clearly

# %%
# 4 agree   5 for strongly agree 1 disagree

# %%
 
    data.plot(x="1Gender of respondent", y="15 What is your preferred payment Option?\t\t\t\t\t                                                                                                                               ", kind="bar", rot=5, fontsize=4)
# Out:
# <AxesSubplot:xlabel='1Gender of respondent'>

# %%
#32 Shopping online is convenient and flexible'
sns.countplot(x="32 Shopping online is convenient and flexible",data=data)
data["32 Shopping online is convenient and flexible"].value_counts()
# Out:
# 5    146
# 4     78
# 3     33
# 2     12
# Name: 32 Shopping online is convenient and flexible, dtype: int64

# %%
# 4 agree ,  5 for strongly agree, 2 disagree,  3  indifferent.

# %%
#Quickness to complete purchase
plt.figure(figsize=(15,7))
sns.countplot(y="Quickness to complete purchase",data=data)
data["Quickness to complete purchase"].value_counts()
# Out:
# Amazon.com                                                   66
# Amazon.com, Flipkart.com, Paytm.com                          47
# Amazon.com, Flipkart.com                                     37
# Amazon.com, Flipkart.com, Myntra.com                         30
# Paytm.com                                                    25
# Amazon.com, Paytm.com, Myntra.com                            20
# Amazon.com, Flipkart.com, Paytm.com, Myntra.com, Snapdeal    15
# Flipkart.com                                                 15
# Flipkart.com, Myntra.com, Snapdeal                           14
# Name: Quickness to complete purchase, dtype: int64

# %%
#33 Return and replacement policy of the e-tailer is important for purchase decision

plt.figure(figsize=(10,5))
sns.countplot(x="33 Return and replacement policy of the e-tailer is important for purchase decision",data=data)
data["33 Return and replacement policy of the e-tailer is important for purchase decision"].value_counts()
# Out:
# 5    198
# 4     51
# 2     20
# Name: 33 Return and replacement policy of the e-tailer is important for purchase decision, dtype: int64

# %%
# 5 strongly agree ,return replace important to for purchase decision that can understand by the graph

# %%
#Longer delivery period


sns.catplot(x='Longer delivery period',kind="count",aspect=2,data=data)
data["Longer delivery period"].value_counts()
# Out:
# Paytm.com                  72
# Snapdeal.com               64
# Flipkart.com               44
# Amazon.in                  37
# Myntra.com                 26
# Paytm.com, Snapdeal.com    26
# Name: Longer delivery period, dtype: int64

# %%
#analysis acording to delivery perod paytm take more time in delivery

# %%
#Limited mode of payment on most products (promotion, sales period)'

sns.catplot(x='Limited mode of payment on most products (promotion, sales period)',kind="count",aspect=3.5,data=data)
data["Limited mode of payment on most products (promotion, sales period)"].value_counts()
# Out:
# Snapdeal.com                87
# Amazon.in                   62
# Flipkart.com                31
# Amazon.in, Flipkart.com     29
# Paytm.com                   25
# Paytm.com, Snapdeal.com     15
# Amazon.in, Paytm.com        13
# Myntra.com, Snapdeal.com     7
# Name: Limited mode of payment on most products (promotion, sales period), dtype: int64

# %%
sns.catplot(x='Speedy order delivery ',kind="count",aspect=3.5,data=data)
data['Speedy order delivery '].value_counts()
# Out:
# Amazon.in                                 107
# Amazon.in, Flipkart.com                    82
# Amazon.in, Flipkart.com, Snapdeal.com      36
# Flipkart.com                               15
# Amazon.in, Flipkart.com, Myntra.com        15
# Flipkart.com, Myntra.com, Snapdeal.com     14
# Name: Speedy order delivery , dtype: int64

# %% [markdown]
# Speedy order delivery

# %% [markdown]
# # service quality, system quality, information quality, trust and net benefit

# %%
#payment options,Smartphones,Younger Consumers,Return Policy,Convenience,User-Friendly,Mobile-Friendliness,Shipping Costs

# %%
#9What is the screen size of your mobile device?\t\t\t\t\t\t                                        ',
sns.catplot(x='10 What is the operating system (OS) of your device?\t\t\t\t                                          ',kind="count",aspect=.9,data=data)
data['10 What is the operating system (OS) of your device?\t\t\t\t                                          '].value_counts()
# Out:
# 1    122
# 2     85
# 3     62
# Name: 10 What is the operating system (OS) of your device?\t\t\t\t                                          , dtype: int64

# %%
sns.catplot(x='14 How much time do you explore the e- retail store before making a purchase decision?                                                                 ',kind="count",aspect=.9,data=data)
data['14 How much time do you explore the e- retail store before making a purchase decision?                                                                 '].value_counts()
# Out:
# 5    123
# 3     71
# 4     46
# 1     15
# 2     14
# Name: 14 How much time do you explore the e- retail store before making a purchase decision?                                                                 , dtype: int64

# %% [markdown]
# 5 indicat more than 15 mint

# %%
plt.figure(figsize=(15,7))
sns.boxplot(data["6 How many times you have made an online purchase in the past 1 year?"],data['2 How old are you? '])

plt.show()

# %%
#Easy to use website or application
sns.catplot(x='Easy to use website or application',kind="count",aspect=3.5,data=data)
data["Easy to use website or application"].value_counts()
# Out:
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    64
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               44
# Amazon.in, Flipkart.com                                         44
# Amazon.in                                                       29
# Amazon.in, Flipkart.com, Paytm.com, Snapdeal.com                22
# Amazon.in, Paytm.com, Myntra.com                                20
# Amazon.in, Flipkart.com, Myntra.com                             19
# Paytm.com                                                       12
# Flipkart.com                                                     8
# Amazon.in, Paytm.com                                             7
# Name: Easy to use website or application, dtype: int64

# %% [markdown]
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com most easy to use

# %%
sns.catplot(x='Wild variety of product on offer',kind="count",aspect=3.5,data=data)
data["Wild variety of product on offer"].value_counts()
# Out:
# Amazon.in, Flipkart.com                              130
# Amazon.in                                             43
# Amazon.in, Myntra.com                                 20
# Flipkart.com, Myntra.com                              15
# Myntra.com                                            15
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com     14
# Amazon.in, Flipkart.com, Paytm.com                    13
# Flipkart.com                                          12
# Paytm.com                                              7
# Name: Wild variety of product on offer, dtype: int64

# %% [markdown]
# Amazon.in, Flipkart.com are provide Wild variety of product on offer.

# %%
#Complete, relevant description information of products
sns.catplot(x='Complete, relevant description information of products',kind="count",aspect=3.5,data=data)
data["Complete, relevant description information of products"].value_counts()
# Out:
# Amazon.in, Flipkart.com                                         100
# Amazon.in                                                        43
# Amazon.in, Flipkart.com, Paytm.com                               24
# Amazon.in, Paytm.com, Myntra.com                                 20
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com     15
# Amazon.in, Flipkart.com, Myntra.com                              15
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com                14
# Snapdeal.com                                                     12
# Flipkart.com, Snapdeal.com                                       11
# Flipkart.com                                                      8
# Amazon.in, Flipkart.com, Snapdeal.com                             7
# Name: Complete, relevant description information of products, dtype: int64

# %% [markdown]
# Amazon.in, Flipkart.com Complete, relevant description information of products maximum people said.

# %%
#Fast loading website speed of website and application
sns.catplot(x='Fast loading website speed of website and application',kind="count",aspect=3.5,data=data)
data["Fast loading website speed of website and application"].value_counts()
# Out:
# Amazon.in                                                       51
# Amazon.in, Paytm.com                                            44
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    30
# Amazon.in, Flipkart.com, Myntra.com                             30
# Amazon.in, Flipkart.com                                         30
# Amazon.in, Flipkart.com, Snapdeal.com                           25
# Amazon.in, Flipkart.com, Paytm.com                              25
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               14
# Snapdeal.com                                                    12
# Flipkart.com                                                     8
# Name: Fast loading website speed of website and application, dtype: int64

# %% [markdown]
# Fast loading website speed of website and application amazon most people agree to this.

# %%
#Reliability of the website or application
sns.catplot(x='Reliability of the website or application',kind="count",aspect=3.5,data=data)
data["Reliability of the website or application"].value_counts()
# Out:
# Amazon.in                                            61
# Amazon.in, Flipkart.com                              50
# Amazon.in, Flipkart.com, Paytm.com                   36
# Amazon.in, Paytm.com, Myntra.com                     35
# Amazon.in, Flipkart.com, Snapdeal.com                18
# Flipkart.com                                         15
# Myntra.com                                           15
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com    14
# Amazon.in, Flipkart.com, Paytm.com, Snapdeal.com     13
# Paytm.com                                            12
# Name: Reliability of the website or application, dtype: int64

# %%
#Quickness to complete purchase
sns.catplot(x='2 How old are you? ',kind="count",aspect=2,data=data)
data['2 How old are you? '].value_counts()
# Out:
# 3    81
# 2    79
# 4    70
# 1    20
# 5    19
# Name: 2 How old are you? , dtype: int64

# %%
sns.catplot(x='Easy to use website or application',kind="count",aspect=3.5,data=data)
data["Easy to use website or application"].value_counts()
# Out:
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    64
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               44
# Amazon.in, Flipkart.com                                         44
# Amazon.in                                                       29
# Amazon.in, Flipkart.com, Paytm.com, Snapdeal.com                22
# Amazon.in, Paytm.com, Myntra.com                                20
# Amazon.in, Flipkart.com, Myntra.com                             19
# Paytm.com                                                       12
# Flipkart.com                                                     8
# Amazon.in, Paytm.com                                             7
# Name: Easy to use website or application, dtype: int64

# %%
sns.catplot(x='Quickness to complete purchase',kind="count",aspect=3.5,data=data)
data["Quickness to complete purchase"].value_counts()
# Out:
# Amazon.com                                                   66
# Amazon.com, Flipkart.com, Paytm.com                          47
# Amazon.com, Flipkart.com                                     37
# Amazon.com, Flipkart.com, Myntra.com                         30
# Paytm.com                                                    25
# Amazon.com, Paytm.com, Myntra.com                            20
# Amazon.com, Flipkart.com, Paytm.com, Myntra.com, Snapdeal    15
# Flipkart.com                                                 15
# Flipkart.com, Myntra.com, Snapdeal                           14
# Name: Quickness to complete purchase, dtype: int64

# %% [markdown]
# amazon have Quickness to complete purchase

# %%
sns.catplot(x='Availability of several payment options',kind="count",aspect=3.5,data=data)

data["Availability of several payment options"].value_counts()
# Out:
# Amazon.in, Flipkart.com                                         65
# Amazon.in, Flipkart.com, Myntra.com                             40
# Amazon.in, Flipkart.com, Patym.com, Myntra.com, Snapdeal.com    39
# Amazon.in                                                       23
# Patym.com, Myntra.com                                           20
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               19
# Amazon.in, Flipkart.com, Snapdeal.com                           18
# Flipkart.com, Myntra.com, Snapdeal.com                          14
# Patym.com                                                       12
# Amazon.in, Patym.com                                            11
# Flipkart.com                                                     8
# Name: Availability of several payment options, dtype: int64

# %%
#Security of customer financial information
sns.catplot(x='Security of customer financial information',kind="count",aspect=3.5,data=data)

data["Security of customer financial information"].value_counts()
# Out:
# Amazon.in                                                       51
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    42
# Flipkart.com                                                    33
# Amazon.in, Flipkart.com, Snapdeal.com                           25
# Amazon.in, Flipkart.com                                         24
# Amazon.in, Paytm.com, Myntra.com                                20
# Amazon.in, Snapdeal.com                                         19
# Myntra.com                                                      15
# Paytm.com                                                       15
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               14
# Amazon.in, Flipkart.com, Paytm.com                              11
# Name: Security of customer financial information, dtype: int64

# %% [markdown]
# most of people said amazon take care security of information

# %%
#Perceived Trustworthiness
sns.catplot(x='Perceived Trustworthiness',kind="count",aspect=3.5,data=data)

data["Perceived Trustworthiness"].value_counts()
# Out:
# Amazon.in                                                       76
# Amazon.in, Flipkart.com, Snapdeal.com                           36
# Amazon.in, Myntra.com                                           35
# Amazon.in, Flipkart.com                                         31
# Flipkart.com                                                    27
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               25
# Myntra.com                                                      15
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    13
# Amazon.in, Flipkart.com, Paytm.com                              11
# Name: Perceived Trustworthiness, dtype: int64

# %% [markdown]
# amazon is most Trustworthiness

# %%
#Presence of online assistance through multi-channel
sns.catplot(x='Presence of online assistance through multi-channel',kind="count",aspect=3.5,data=data)

data["Presence of online assistance through multi-channel"].value_counts()
# Out:
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal    61
# Amazon.in                                        60
# Amazon.in, Flipkart.com                          39
# Amazon.in, Snapdeal                              26
# Myntra.com                                       20
# Amazon.in, Flipkart.com, Myntra.com              15
# Amazon.in, Myntra.com                            15
# Amazon.in, Flipkart.com, Paytm.com               13
# Paytm.com                                        12
# Flipkart.com                                      8
# Name: Presence of online assistance through multi-channel, dtype: int64

# %% [markdown]
# Presence of online assistance through multi-channel is bater in Amazon.in, Flipkart.com, Myntra.com, Snapdeal
# Amazon.in

# %%
#Longer time to get logged in (promotion, sales period)
sns.catplot(x='Longer time to get logged in (promotion, sales period)',kind="count",aspect=3.5,data=data)

data["Longer time to get logged in (promotion, sales period)"].value_counts()
# Out:
# Amazon.in                                57
# Paytm.com                                38
# Amazon.in, Flipkart.com                  38
# Myntra.com                               35
# Amazon.in, Flipkart.com, Snapdeal.com    29
# Snapdeal.com                             25
# Flipkart.com, Paytm.com                  15
# Flipkart.com, Paytm.com, Snapdeal.com    13
# Amazon.in, Paytm.com                     11
# Flipkart.com                              8
# Name: Longer time to get logged in (promotion, sales period), dtype: int64

# %% [markdown]
# at sales time or offer time Amazon.in take  Longer time to get logged in (promotion, sales period)

# %%
#Longer time in displaying graphics and photos (promotion, sales period)
sns.catplot(x='Longer time in displaying graphics and photos (promotion, sales period)',kind="count",aspect=3.5,data=data)

data["Longer time in displaying graphics and photos (promotion, sales period)"].value_counts()
# Out:
# Amazon.in, Flipkart.com                60
# Amazon.in                              39
# Myntra.com                             35
# Snapdeal.com                           34
# Myntra.com, Snapdeal.com               25
# Flipkart.com, Snapdeal.com             19
# Flipkart.com                           15
# Paytm.com                              15
# Amazon.in, Myntra.com, Snapdeal.com    14
# Amazon.in, Paytm.com                   13
# Name: Longer time in displaying graphics and photos (promotion, sales period), dtype: int64

# %%
#Late declaration of price (promotion, sales period)
sns.catplot(x='Late declaration of price (promotion, sales period)',kind="count",aspect=3.5,data=data)

data["Late declaration of price (promotion, sales period)"].value_counts()
# Out:
# Myntra.com                 75
# Paytm.com                  52
# snapdeal.com               41
# Flipkart.com               38
# Amazon.in                  38
# Amazon.in, Paytm.com       13
# Paytm.com, snapdeal.com     7
# Amazon.in, Flipkart.com     5
# Name: Late declaration of price (promotion, sales period), dtype: int64

# %% [markdown]
# maximum people saied myntra take Late declaration of price (promotion, sales period)

# %%
#Longer page loading time (promotion, sales period)
sns.catplot(x='Longer page loading time (promotion, sales period)',kind="count",aspect=3.5,data=data)

data["Longer page loading time (promotion, sales period)"].value_counts()
# Out:
# Myntra.com                          61
# Paytm.com                           59
# Flipkart.com                        32
# Snapdeal.com                        23
# Amazon.in, Flipkart.com             18
# Amazon.in                           16
# Paytm.com, Snapdeal.com             15
# Amazon.in, Snapdeal.com             14
# Amazon.in, Paytm.com                13
# Flipkart.com, Snapdeal.com          11
# Amazon.in, Paytm.com, Myntra.com     7
# Name: Longer page loading time (promotion, sales period), dtype: int64

# %% [markdown]
# myntra paytm has more Longer page loading time (promotion, sales period)

# %%
#Longer page loading time (promotion, sales period)
sns.catplot(x='Longer page loading time (promotion, sales period)',kind="count",aspect=3.5,data=data)

data["Longer page loading time (promotion, sales period)"].value_counts()
# Out:
# Myntra.com                          61
# Paytm.com                           59
# Flipkart.com                        32
# Snapdeal.com                        23
# Amazon.in, Flipkart.com             18
# Amazon.in                           16
# Paytm.com, Snapdeal.com             15
# Amazon.in, Snapdeal.com             14
# Amazon.in, Paytm.com                13
# Flipkart.com, Snapdeal.com          11
# Amazon.in, Paytm.com, Myntra.com     7
# Name: Longer page loading time (promotion, sales period), dtype: int64

# %%
#Limited mode of payment on most products (promotion, sales period)
sns.catplot(x='Limited mode of payment on most products (promotion, sales period)',kind="count",aspect=3.5,data=data)

data["Limited mode of payment on most products (promotion, sales period)"].value_counts()
# Out:
# Snapdeal.com                87
# Amazon.in                   62
# Flipkart.com                31
# Amazon.in, Flipkart.com     29
# Paytm.com                   25
# Paytm.com, Snapdeal.com     15
# Amazon.in, Paytm.com        13
# Myntra.com, Snapdeal.com     7
# Name: Limited mode of payment on most products (promotion, sales period), dtype: int64

# %% [markdown]
# snapdeal.com have large limited payment mode

# %%
#Longer delivery period
sns.catplot(x='Longer delivery period',kind="count",aspect=3,data=data)

data["Longer delivery period"].value_counts()
# Out:
# Paytm.com                  72
# Snapdeal.com               64
# Flipkart.com               44
# Amazon.in                  37
# Myntra.com                 26
# Paytm.com, Snapdeal.com    26
# Name: Longer delivery period, dtype: int64

# %% [markdown]
# paytm and snapdeal has Longer delivery period

# %%
#Frequent disruption when moving from one page to another
sns.catplot(x='Frequent disruption when moving from one page to another',kind="count",aspect=3,data=data)

data["Frequent disruption when moving from one page to another"].value_counts()
# Out:
# Amazon.in                     53
# Myntra.com                    52
# Snapdeal.com                  49
# Paytm.com                     39
# Flipkart.com                  26
# Amazon.in, Flipkart.com       25
# Myntra.com, Snapdeal.com      14
# Flipkart.com, Snapdeal.com    11
# Name: Frequent disruption when moving from one page to another, dtype: int64

# %% [markdown]
# Frequent disruption when moving from one page to another Amazon.in
# Myntra.com
# Snapdeal.com

# %%
#'Which of the Indian online retailer would you recommend to a friend?'
sns.catplot(x='Which of the Indian online retailer would you recommend to a friend?',kind="count",aspect=3,data=data)

data['Which of the Indian online retailer would you recommend to a friend?'].value_counts()
# Out:
# Amazon.in                                            79
# Amazon.in, Flipkart.com                              62
# Flipkart.com                                         39
# Amazon.in, Myntra.com                                30
# Amazon.in, Paytm.com, Myntra.com                     20
# Amazon.in, Flipkart.com, Myntra.com                  15
# Amazon.in, Paytm.com                                 13
# Flipkart.com, Paytm.com, Myntra.com, snapdeal.com    11
# Name: Which of the Indian online retailer would you recommend to a friend?, dtype: int64

# %%
#'Website is as efficient as before'
sns.catplot(x='Website is as efficient as before',kind="count",aspect=3,data=data)

data['Website is as efficient as before'].value_counts()
# Out:
# Amazon.in                             94
# Flipkart.com                          47
# Amazon.in, Flipkart.com               45
# Amazon.in, Flipkart.com, Paytm.com    25
# Amazon.in, Paytm.com                  18
# Paytm.com                             15
# Myntra.com, Snapdeal.com              14
# Snapdeal.com                          11
# Name: Website is as efficient as before, dtype: int64

# %%
#'47 Getting value for money spent'
sns.catplot(x='47 Getting value for money spent',kind="count",aspect=.9,data=data)

data['47 Getting value for money spent'].value_counts()
# Out:
# 4    149
# 5     82
# 3     38
# Name: 47 Getting value for money spent, dtype: int64

# %% [markdown]
# in the surway most people says 47 Getting value for money spent

# %%
#'46 Shopping on the website helps you fulfill certain roles'
sns.catplot(x='46 Shopping on the website helps you fulfill certain roles',kind="count",aspect=.9,data=data)

data['46 Shopping on the website helps you fulfill certain roles'].value_counts()
# Out:
# 3    88
# 4    88
# 5    38
# 1    33
# 2    22
# Name: 46 Shopping on the website helps you fulfill certain roles, dtype: int64

# %%
 sns.countplot(x="15 What is your preferred payment Option?\t\t\t\t\t                                                                                                                               ",data=data)
# Out:
# <AxesSubplot:xlabel='15 What is your preferred payment Option?\t\t\t\t\t                                                                                                                               ', ylabel='count'>

# %% [markdown]
# 1 for debit/credit card********    2 for cash on delivery *******   4 for E wallet

# %%
plt.figure(figsize=(15,7))
sns.barplot(x='3 Which city do you shop online from?',y='1Gender of respondent',data=data,hue="1Gender of respondent")
# Out:
# <AxesSubplot:xlabel='3 Which city do you shop online from?', ylabel='1Gender of respondent'>
