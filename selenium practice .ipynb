# %%
import pandas as pd
import selenium
from selenium import webdriver
import warnings
warnings.filterwarnings("ignore")

# %%
driver=webdriver.Chrome(r'C:\Users\RUCHITA\Downloads\chromedriver_win32/chromedriver.exe')

# %%
#1. First get the webpage https://www.naukri.com/
url='https://www.naukri.com/'
driver.get(url)

# %%
#2. Enter “Data Analyst” in “Skill, Designations, Companies” field
search_job=driver.find_element_by_class_name("suggestor-input")
search_job
search_job.send_keys("Data Analyst")

# %%
# enter “Bangalore” in “enter the loction field

search_loc=driver.find_element_by_xpath('/html/body/div/div[2]/div[3]/div/div/div[3]/div/div/div/input')
search_loc
search_loc.send_keys("Bangalore")

# %%
search_btn=driver.find_element_by_xpath('/html/body/div/div[2]/div[3]/div/div/div[6]')
search_btn
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="81896f9fc12186617687d0e7942ef120", element="f39fab43-7b5d-4448-8bfe-8075deeee627")>

# %%
search_btn.click()

# %%
title_tags=driver.find_elements_by_xpath('//a[@class="title fw500 ellipsis"]')
title_tags
job_title=[]
for i in title_tags:
    job_title.append(i.text)
del job_title[10:21]

# %%
company_tag=driver.find_elements_by_xpath('//a[@class="subTitle ellipsis fleft"]')
company_name=[]
for i in company_tag:
    company_name.append(i.text)
del company_name[10:21]

# %%
location_tag=driver.find_elements_by_xpath('//li[@class="fleft grey-text br2 placeHolderLi location"]')
location=[]
for i in location_tag:
    location.append(i.text)
del location[10:21]
location
# Out:
# ['Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Ahmedabad, Bangalore/Bengaluru',
#  'Pune, Bangalore/Bengaluru(Shivaji Nagar), Mumbai (All Areas)\n(WFH during Covid)',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru']

# %%
len(company_name)
# Out:
# 10

# %%
exp_tag=driver.find_elements_by_xpath('//li[@class="fleft grey-text br2 placeHolderLi experience"]')
experience=[]
for i in exp_tag:
    experience.append(i.text)
del experience[10:21]

# %%
len(experience),len(company_name),len(location),len(job_title)
# Out:
# (10, 10, 10, 10)

# %%
#Finally create a dataframe of the scraped data
import pandas as pd
df=pd.DataFrame()
df['job_titles']=job_title
df['company']=company_name
df['experience']=experience
df['locations']=location
df
# Out:
#                                           job_titles  \
# 0                          Flight data analyst (372)
# 1                                Senior Data Analyst
# 2                                Senior Data Analyst
# 3                           Looking For Data Analyst
# 4  software developer & Testing / Business Analys...
# 5                  Staff Business Data Analyst - FDP
# 6             Data Analyst - IIM/ISB/MDI/FMS/SP Jain
# 7                                Senior Data Analyst
# 8                                Senior Data Analyst
# 9   Senior Data Analyst (Digital Services Analytics)
#
#                                company experience  \
# 0         NEST DIGITAL PRIVATE LIMITED    0-1 Yrs
# 1                                Capco    4-8 Yrs
# 2                Mobile Premier League    3-6 Yrs
# 3                            Trellance    0-2 Yrs
# 4  SECRET TECHNOLOGIES INDIA VMS GROUP    0-4 Yrs
# 5                          Intuit Inc.    5-7 Yrs
# ...

# %% [markdown]
# # 2: Write a python program to scrape data for “Data Scientist” Job position in “Bangalore” location. You
# have to scrape the job-title, job-location, company_name. You have to scrape first 10 jobs data.
# This task will be done in following steps:

# %%
#1. First get the webpage https://www.naukri.com/
url='https://www.naukri.com/'
driver.get(url)

# %%
#2. Enter “Data Science” in “Skill, Designations, Companies” field
search_job=driver.find_element_by_class_name("suggestor-input")
search_job
search_job.send_keys("Data Scientist")

# %%
# enter “Bangalore” in “enter the loction field

search_loc=driver.find_element_by_xpath('/html/body/div/div[2]/div[3]/div/div/div[3]/div/div/div/input')
search_loc
search_loc.send_keys("Bangalore")

# %%
search_btn=driver.find_element_by_xpath('/html/body/div/div[2]/div[3]/div/div/div[6]')
search_btn
search_btn.click()

# %%
title_tags=driver.find_elements_by_xpath('//a[@class="title fw500 ellipsis"]')
title_tags
job_title=[]
for i in title_tags:
    job_title.append(i.text)
del job_title[10:21]

# %%
company_tag=driver.find_elements_by_xpath('//a[@class="subTitle ellipsis fleft"]')
company_name=[]
for i in company_tag:
    company_name.append(i.text)
del company_name[10:21]
#company_name

# %%
location_tag=driver.find_elements_by_xpath('//li[@class="fleft grey-text br2 placeHolderLi location"]')
location=[]
for i in location_tag:
    location.append(i.text)
del location[10:21]
location
# Out:
# ['Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Gurgaon/Gurugram, Bangalore/Bengaluru\n(WFH during Covid)',
#  'Navi Mumbai, New Delhi, Bangalore/Bengaluru',
#  'Chennai, Bangalore/Bengaluru\n(WFH during Covid)',
#  'Bangalore/Bengaluru',
#  'Chennai, Bangalore/Bengaluru\n(WFH during Covid)',
#  'Noida, Kolkata, Hyderabad/Secunderabad, Pune, Chennai, Bangalore/Bengaluru, Delhi / NCR, Mumbai (All Areas)\n(WFH during Covid)',
#  'Bangalore/Bengaluru']

# %%
df=pd.DataFrame()
df['job_titles']=job_title
df['company']=company_name
df['locations']=location
df
# Out:
#                                           job_titles  \
# 0                           Data Scientist / Analyst
# 1                              Senior Data Scientist
# 2         Data Scientist II- Merchandise & Discovery
# 3    Forecasting Analyst/ Data Scientist (US Client)
# 4                 Consultant - Junior Data Scientist
# 5                                     Data Scientist
# 6                                     Data Scientist
# 7                           Principal Data Scientist
# 8  Excellent Opportunity For Freshers For AI/ML, ...
# 9                              Junior Data Scientist
#
#                                         company  \
# 0                              open data fabric
# 1                                      newscorp
# 2                                        Swiggy
# 3                                    Concentrix
# 4                                    Flexing It
# 5  VANTAGEIQ TECHNOLOGIES (OPC) PRIVATE LIMITED
# ...

# %% [markdown]
# # 3: In this question you have to scrape data using the filters available on the webpage as shown below

# %%
#1. First get the webpage https://www.naukri.com/
url='https://www.naukri.com/'
driver.get(url)

# %%
#2. Enter “Data Science” in “Skill, Designations, Companies” field
search_job=driver.find_element_by_class_name("suggestor-input")
search_job
search_job.send_keys("Data Scientist")

# %%
search_btn=driver.find_element_by_xpath('/html/body/div/div[2]/div[3]/div/div/div[6]')
search_btn
search_btn.click()

# %%
location=driver.find_element_by_xpath('/html/body/div[1]/div[3]/div[2]/section[1]/div[2]/div[3]/div[2]/div[3]/label/i')
location.click()

# %%
salary_chk=driver.find_element_by_xpath('/html/body/div[1]/div[3]/div[2]/section[1]/div[2]/div[4]/div[2]/div[2]/label/i')
salary_chk.click()

# %%
title_tags=driver.find_elements_by_xpath('//a[@class="title fw500 ellipsis"]')
title_tags
job_title=[]
for i in title_tags:
    job_title.append(i.text)
del job_title[10:21]

# %%
company_tag=driver.find_elements_by_xpath('//a[@class="subTitle ellipsis fleft"]')
company_name=[]
for i in company_tag:
    company_name.append(i.text)
del company_name[10:21]

# %%
location_tag=driver.find_elements_by_xpath('//li[@class="fleft grey-text br2 placeHolderLi location"]')
location=[]
for i in location_tag:
    location.append(i.text)
del location[10:21]

# %%
df=pd.DataFrame()
df['job_titles']=job_title
df['company']=company_name
df['locations']=location
df
# Out:
#                                           job_titles  \
# 0  Excellent Opportunity For Freshers For AI/ML, ...
# 1   Junior Data Analyst/ Scientist- Fresher Position
# 2  Only Fresher / Python Data Scientist / Trainee...
# 3                                     Data Scientist
# 4                     Data Scientist - MIND Infotech
# 5                     Data Scientist - MIND Infotech
# 6                          Hiring For Data Scientist
# 7                                Lead Data Scientist
# 8      Urgent Requirement || Data Scientist || Noida
# 9  Data Analyst / Data Scientist / Business Analy...
#
#                                     company  \
# 0                                  NTT Data
# 1                      Sejal Consulting Hub
# 2                 GABA Consultancy services
# 3                                     Optum
# 4  MOTHERSONSUMI INFOTECH & DESIGNS LIMITED
# 5  MOTHERSONSUMI INFOTECH & DESIGNS LIMITED
# 6                                  Lumiq.ai
# ...

# %% [markdown]
# # Q4: Scrape data of first 100 sunglasses listings on flipkart.com. You have to scrape four attributes:
# 1. Brand
# 2. Product Description
# 3. Price

# %%
#1. First get the webpage https://www.naukri.com/
url='https://www.flipkart.com/'
driver.get(url)

# %%
search_job=driver.find_element_by_class_name("_3704LK")
search_job
search_job.send_keys("sunglasses")

# %%
search_btn=driver.find_element_by_class_name('L0Z3Pu')
search_btn
search_btn.click()

# %%
product_name=driver.find_elements_by_class_name("_2WkVRV")
product_name
product=[]
for i in product_name:
    product.append(i.text)
product[0:2]
# Out:
# ['AISLIN', 'ROZZETTA CRAFT']

# %%
product_detail=driver.find_elements_by_class_name("IRpwTa")
product_detail
details=[]
for i in product_detail:
    details.append(i.text)
details[0:2]
# Out:
# ['UV Protection, Gradient Cat-eye Sunglasses (58)',
#  'UV Protection, Gradient Retro Square Sunglasses (Free S...']

# %%
product_price=driver.find_elements_by_class_name("_30jeq3")
product_price
price=[]
for i in product_price:
    price.append(i.text)
del price[40:46]

# %%
df=pd.DataFrame()
df['products_name']=product
df['product_details']=details
df['product_price']=price
df
# Out:
#         products_name                                    product_details  \
# 0          PHENOMENAL  UV Protection, Mirrored Retro Square Sunglasse...
# 1             DEIXELS      UV Protection Wayfarer Sunglasses (Free Size)
# 2          Lee Topper  UV Protection, Riding Glasses Retro Square, Sp...
# 3        LOUIS KOUROS              UV Protection Aviator Sunglasses (60)
# 4            Fastrack  Gradient, UV Protection Wayfarer Sunglasses (F...
# 5           New Specs  UV Protection, Mirrored Sports Sunglasses (Fre...
# 6        Silver Kartz      UV Protection Wayfarer Sunglasses (Free Size)
# 7        LOUIS KOUROS              UV Protection Aviator Sunglasses (60)
# 8              SUNBEE  UV Protection, Polarized, Mirrored Retro Squar...
# 9           ROYAL SON          UV Protection Rectangular Sunglasses (58)
# 10           Fastrack      UV Protection Wayfarer Sunglasses (Free Size)
# 11              NuVew              UV Protection Aviator Sunglasses (57)
# ...

# %%
next_btn=driver.find_element_by_class_name('_1LKTO3')
next_btn
next_btn.click()

# %%
product_name=driver.find_elements_by_class_name("_2WkVRV")
product_name
product=[]
for i in product_name:
    product.append(i.text)
product[0:2]
product_detail=driver.find_elements_by_class_name("IRpwTa")
product_detail
details=[]
for i in product_detail:
    details.append(i.text)
details[0:2]
product_price=driver.find_elements_by_class_name("_30jeq3")
product_price
price=[]
for i in product_price:
    price.append(i.text)
del price[40:46]

# %%
df=pd.DataFrame()
df['products_name']=product
df['product_details']=details
df['product_price']=price
df
# Out:
#         products_name                                    product_details  \
# 0          IZAAN MART          UV Protection Rectangular Sunglasses (55)
# 1              AISLIN    UV Protection, Gradient Cat-eye Sunglasses (58)
# 2                SRPM             UV Protection Wayfarer Sunglasses (50)
# 3              PIRASO              UV Protection Aviator Sunglasses (54)
# 4           New Specs   UV Protection Rectangular Sunglasses (Free Size)
# 5             DEIXELS  UV Protection Aviator, Wayfarer Sunglasses (Fr...
# 6            Fastrack   UV Protection Rectangular Sunglasses (Free Size)
# 7      ROZZETTA CRAFT  UV Protection, Gradient Retro Square Sunglasse...
# 8   SHAAH COLLECTIONS  UV Protection, Polarized, Mirrored Rectangular...
# 9          Lee Topper  Riding Glasses Wrap-around Sunglasses (Free Size)
# 10               SRPM      Others Wayfarer, Retro Square Sunglasses (50)
# 11        SKYZA INDIA  Polarized, UV Protection Sports Sunglasses (Fr...
# ...

# %%
# importing necessary packages
from selenium import webdriver
#from webdriver_manager.chrome import ChromeDriverManager
  
# for holding the resultant list
element_list = []
  
for page in range(1,3,1):
    
    page_url = "https://www.flipkart.com/search?q=sunglasses&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=1" + str(page)
    driver=webdriver.Chrome(r'C:\Users\RUCHITA\Downloads\chromedriver_win32/chromedriver.exe')
    driver.get(page_url)
    title = driver.find_elements_by_class_name("_2WkVRV")
    price = driver.find_elements_by_class_name("_30jeq3")
    description = driver.find_elements_by_class_name("IRpwTa")
    #rating = driver.find_elements_by_class_name("ratings")
  
    for i in range(len(title)):
        element_list.append([title[i].text, price[i].text, description[i].text])
element_list
# Out:
# [['agera', '₹104', 'UV Protection Round Sunglasses (56)'],
#  ['ROYAL SON', '₹614', 'UV Protection Cat-eye, Over-sized Sunglasses (62)'],
#  ['Singco India',
#   '₹246',
#   'UV Protection, Mirrored, Others Aviator Sunglasses (33)'],
#  ['LOUIS KOUROS', '₹1,299', 'UV Protection Aviator Sunglasses (60)'],
#  ['VINCENT CHASE',
#   '₹949',
#   'by Lenskart Polarized, UV Protection Round Sunglasses (...'],
#  ['ROYAL SON', '₹519', 'UV Protection Retro Square Sunglasses (60)'],
#  ['Urbanic', '₹499', 'Others Retro Square Sunglasses (Free Size)'],
#  ['ROYAL SON',
#   '₹614',
#   'UV Protection, Gradient Butterfly, Over-sized Sunglasse...'],
#  ['hipe', '₹94', 'UV Protection, Gradient, Mirrored, Riding Glasses, Nigh...'],
#  ['Fastrack', '₹759', 'UV Protection Wayfarer Sunglasses (56)'],
#  ['ROYAL SON', '₹329', 'UV Protection Round Sunglasses (50)'],
#  ['ROYAL SON', '₹614', 'UV Protection, Gradient Butterfly Sunglasses (52)'],
# ...

# %% [markdown]
# # 6 : Scrape data for first 100 sneakers you find when you visit flipkart.com andsearch for “sneakers” in the
# search field

# %%
import pandas as pd
import selenium
from selenium import webdriver
import warnings
warnings.filterwarnings("ignore")

# %%
driver=webdriver.Chrome(r'C:/Users/RUCHITA/Downloads/chromedriver_win32/chromedriver.exe')

# %%
url='https://www.flipkart.com/'
driver.get(url)

# %%
search_job=driver.find_element_by_class_name("_3704LK")
search_job
search_job.send_keys("sneaker")

# %%
search_btn=driver.find_element_by_class_name('L0Z3Pu')
search_btn
search_btn.click()

# %%
product_name=driver.find_elements_by_class_name("_2WkVRV")
product_name
product=[]
for i in product_name:
    product.append(i.text)
product[0:2]
# Out:
# ['Magnolia', 'Chevit']

# %%
price_product=driver.find_elements_by_class_name("_30jeq3")
price_product
price=[]
for i in price_product:
    price.append(i.text)
del price[40:46]

# %%
product_details=driver.find_elements_by_class_name("IRpwTa")

details=[]
for i in product_details:
    details.append(i.text)
details[0:2]
# Out:
# ['Sneakers For Men',
#  'Super Stylish & Trendy Combo Pack of 02 Pairs Sneakers ...']

# %%
next_btn=driver.find_element_by_class_name('_1LKTO3')
next_btn
next_btn.click()

# %%
len(details)
# Out:
# 40

# %%
df=pd.DataFrame()
df['products_name']=product
df['product_details']=details
df['product_price']=price
df
# Out:
#             products_name                                    product_details  \
# 0                ASTEROID          sneaker men red 1258 - 6 Sneakers For Men
# 1             Shoes villa                                   Sneakers For Men
# 2                  Chevit                          Shark-41 Sneakers For Men
# 3                  Kzaara  Ultralight Latest Collection Sports Running Sh...
# 4                Magnolia  Combo Pack Of 2 Latest Stylish Casual Shoes fo...
# 5                  BRUTON  white Casual shoes,Sneakers for men's Sneakers...
# 6                  Kraasa                           Sneaker Sneakers For Men
# 7                RapidBox  Kwik FIT casual sneaker shoes and partywear sh...
# 8                URBANBOX  Men 5014 Latest Collection Stylish Casual Spor...
# 9     World Wear Footwear  Casual Sneakers Shoes for Men Pack of 5 Combo(...
# 10                 corsac             Lattest Sneakers Shoe Sneakers For Men
# ...

# %% [markdown]
# # 7: Go to the link - https://www.myntra.com/shoes
# Set Price filter to “Rs. 7149 to Rs. 14099 ” , Color filter to “Black”, as shown inthe below imag

# %%
driver=webdriver.Chrome(r'C:\Users\RUCHITA\Downloads\chromedriver_win32/chromedriver.exe')

# %%
url=' https://www.myntra.com/shoes'
driver.get(url)

# %%
price=driver.find_element_by_xpath('/html/body/div[2]/div/div[1]/main/div[3]/div[1]/section/div/div[5]/ul/li[2]/label')

# %%
driver.implicitly_wait(10)
price.click()

# %%
colr=driver.find_element_by_xpath('/html/body/div[2]/div/div[1]/main/div[3]/div[1]/section/div/div[6]/ul/li[1]/label/div')
driver.implicitly_wait(10)
colr.click()

# %%
price_product=driver.find_elements_by_class_name("product-price")

price=[]
for i in price_product:
    price.append(i.text)
price[0:2]
# Out:
# ['Rs. 9099Rs. 12999(30% OFF)', 'Rs. 12999']

# %%
details=driver.find_elements_by_class_name("product-product")
detail=[]
for i in details:
    detail.append(i.text)
detail[0:2]
# Out:
# ['Men Printed Sneakers', 'Men Leather Driving Shoes']

# %%
brand=driver.find_elements_by_class_name("product-brand")
brand_name=[]
for i in brand:
    brand_name.append(i.text)
brand_name[0:2]
# Out:
# ['ALDO', 'ALDO']

# %%
next_btn=driver.find_element_by_xpath('/html/body/div[2]/div/div[1]/main/div[3]/div[2]/div/div[2]/section/div[2]/ul/li[12]/a')

next_btn.click()

# %%
df=pd.DataFrame()
df['brand']=brand_name
df['product_details']=detail
df['product_price']=price
df

# %% [markdown]
# # Q8: Go to webpage https://www.amazon.in/
# Enter “Laptop” in the search field and then click the search icon.
# Then set CPU Type filter to “Intel Core i7” and “Intel Core i9” as shown in the below image:

# %%
driver=webdriver.Chrome(r'C:\Users\RUCHITA\Downloads\chromedriver_win32/chromedriver.exe')

# %%
url='https://www.amazon.in'
driver.get(url)

# %%
search_itm=driver.find_element_by_xpath('/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[2]/div[1]/input')

search_itm.send_keys("Laptop")

# %%
search_btn=driver.find_element_by_xpath('/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[3]/div')
search_btn.click()

# %%
cpu_type=driver.find_element_by_xpath('/html/body/div[1]/div[2]/div[1]/div[2]/div/div[3]/span/div[1]/div/div/div[6]/ul[4]/li[13]/span/a/div/label/i')
driver.implicitly_wait(10)
cpu_type.click()

# %%
cpu9=driver.find_element_by_xpath('/html/body/div[1]/div[2]/div[1]/div[2]/div/div[3]/span/div[1]/div/div/div[6]/ul[4]/li[13]/span/a/div/label/i')
driver.implicitly_wait(10)
cpu9.click()

# %%
title_tags=driver.find_elements_by_xpath('/html/body/div[1]/div[2]/div[1]/div[1]/div/span[3]/div[2]/div[5]/div/div/div/div/div/div[2]/div/div/div[1]/h2/a')
#title_tag=driver.find_elements_by_class_name("a-size-mini a-spacing-none a-color-base s-line-clamp-2")
laptop=[]
for i in title_tags:
    laptop.append(i.text)
laptop
# Out:
# ['ASUS ROG Strix Scar 17 (2022), 17.3-inch (43.94 cms) 2K WQHD 240Hz/3ms, Core i9-12900H 12th Gen, RTX 3070 Ti 8GB Graphics, Gaming Laptop (32GB/2TB SSD/Win 11/Office 2021/Black/2.9 Kg), G733ZW-LL105WS']

# %%
rating=driver.find_elements_by_class_name("a-icon-alt")

rating_tag=[]
for i in rating:
    rating_tag.append(i.text)
rating_tag
# Out:
# ['',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '']

# %%
price=driver.find_elements_by_class_name("a-price-whole")
mrp=[]
for i in price:
    mrp.append(i.text)
mrp[10:21]
# Out:
# ['1,38,000',
#  '2,93,000',
#  '1,72,000',
#  '2,99,990',
#  '2,25,000',
#  '44,490',
#  '59,990',
#  '5,474.',
#  '4,499.',
#  '6,136.',
#  '2,998.']

# %%
len(rating_tag)
# Out:
# 1

# %% [markdown]
# # Q9: Write a python program to scrape data for first 10 job results for Data Scientist Designation in Noida
# location. You have to scrape company name, No. of days ago when job was posted, Rating of the company.
# This task will be done in following steps:
# 1. First get the webpage https://www.ambitionbox.com/
# 2. Click on the Job option as shown in the image

# %%
driver=webdriver.Chrome(r'C:\Users\RUCHITA\Downloads\chromedriver_win32/chromedriver.exe')

# %%
url='https://www.ambitionbox.com/jobs'
driver.get(url)

# %%
search_itm=driver.find_element_by_xpath('/html/body/div/div/div/div[2]/div[1]/div/div/div/div/span/input')

#search_itm.send_keys("Data Scientist")

# %%
search_itm.send_keys("data scientist")

# %%
search_btn=driver.find_element_by_class_name('ctas-btn-medium')
search_btn.click()

# %%
search_btn=driver.find_element_by_class_name('ctas-btn-medium')
search_btn
search_btn.click()

# %%
search_loca=driver.find_element_by_xpath('/html/body/div/div/div/div[2]/div[2]/div[1]/div/div/div/div[2]/div[1]/i')

# %%
#location=driver.find_element_by_xpath('/html/body/div[1]/div[3]/div[2]/section[1]/div[2]/div[3]/div[2]/div[3]/label/i')
search_loca.click()

# %%
search_city=driver.find_element_by_xpath('/html/body/div/div/div/div[2]/div[2]/div[1]/div/div/div/div[2]/div[2]/div/div[3]/div[1]/div[4]/div/label')

search_city.click()

# %%
company_tag=driver.find_elements_by_xpath('//p[@class="company body-medium"]')
company_name=[]
for i in company_tag:
    company_name.append(i.text)
company_name
# Out:
# ['NTT DATA GLOBAL DELIVERY SERVICES PRIVATE LIMITED',
#  'HCL Technologies Limited',
#  'Optum Global Solutions (India) Private Limited',
#  'WSP CONSULTANTS INDIA PRIVATE LIMITED',
#  'Microsoft India (R and D) Pvt Ltd',
#  'HCL Technologies Ltd',
#  'Jubilant Foodworks Limited',
#  'HCL Technologies',
#  'RATEGAIN TRAVEL TECHNOLOGIES LIMITED',
#  'Hanu Software Solutions Pvt Ltd']

# %%
info_dayago=driver.find_elements_by_xpath('//span[@class="body-small-l"]')
day_ago=[]
for i in info_dayago:
    day_ago.append(i.text)
del day_ago[10:21]

# %%
rating=driver.find_elements_by_xpath('//span[@class="body-small"]')
rat=[]
for i in rating:
    rat.append(i.text)
rat
# Out:
# ['3.9', '3.8', '4.1', '4.2', '4.2', '3.8', '3.9', '3.8', '3.8', '3.7']

# %%
len(company_name)
# Out:
# 10

# %%
df=pd.DataFrame()
df['company_name']=company_name
df['post_dayago']=day_ago
df['rating']=rat
df
# Out:
#                                         company_name     post_dayago rating
# 0  NTT DATA GLOBAL DELIVERY SERVICES PRIVATE LIMITED          8d ago    3.9
# 1                           HCL Technologies Limited  via naukri.com    3.8
# 2     Optum Global Solutions (India) Private Limited          9d ago    4.1
# 3              WSP CONSULTANTS INDIA PRIVATE LIMITED  via naukri.com    4.2
# 4                  Microsoft India (R and D) Pvt Ltd         19d ago    4.2
# 5                               HCL Technologies Ltd  via naukri.com    3.8
# 6                         Jubilant Foodworks Limited         10d ago    3.9
# 7                                   HCL Technologies  via naukri.com    3.8
# 8               RATEGAIN TRAVEL TECHNOLOGIES LIMITED         20d ago    3.8
# 9                    Hanu Software Solutions Pvt Ltd  via naukri.com    3.7

# %% [markdown]
# # Q10: Write a python program to scrape the salary data for Data Scientist designation.
# You have to scrape Company name, Number of salaries, Average salary, Minsalary, Max Salary

# %%
driver=webdriver.Chrome(r'C:\Users\RUCHITA\Downloads\chromedriver_win32/chromedriver.exe')

# %%
url='https://www.ambitionbox.com/jobs'
driver.get(url)

# %%
salary=driver.find_element_by_xpath('/html/body/div/div/div/div[1]/header/div/div[1]/div/div[3]/a')

# %%
salary.click()

# %%
search_job=driver.find_element_by_xpath('/html/body/div/div/div/main/section[1]/div[2]/div[1]/span/input')

# %%
ds=search_job.send_keys("data scientist")

# %%
ser=driver.find_element_by_class_name("icon-search")
